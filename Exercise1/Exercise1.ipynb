# %%
# %matplotlib inline
import pymc3 as pm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %config InlineBackend.figure_formats = ['retina']
plt.rc('font', size=12)
plt.style.use('seaborn-darkgrid')
# Out:
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'
# /home/rosgori/Python/pymc3_env/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# 1. generate the artificial dataset. The distribution is mu=0.5, sd=0.35
obs_y = np.random.normal(0.5, 0.35, 1000)

# %%
# 2. model that data with a simple Bayesian model.
with pm.Model() as exercise1:

    stdev = pm.HalfNormal('stdev', sd=1.)
    mu = pm.Normal('mu', mu=0.0, sd=1.)

    y = pm.Normal('y', mu=mu, sd=stdev, observed=obs_y)

# %%
with exercise1:
    trace = pm.sample(1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu, stdev]
# Sampling 4 chains: 100%|██████████| 6000/6000 [00:02<00:00, 2673.76draws/s]
# The acceptance probability does not match the target. It is 0.8932975707945663, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
pm.traceplot(trace, ['mu', 'stdev']);
